# %%
import pandas as pd

raw_df = pd.read_csv("/Users/sngirish/personal_work/mtech-learning/data-science/project/Media-Bias-Analysis-in-Indian-News-Articles/articles/raw/indian_express_article_content_2024_progress_50.csv")

# %%
raw_df.head()
# Out:
#    success                                                url  \
# 0     True  https://indianexpress.com/article/cities/pune/...
# 1     True  https://indianexpress.com/article/cities/mumba...
# 2     True  https://indianexpress.com/article/cities/chenn...
# 3     True  https://indianexpress.com/article/cities/mumba...
# 4     True  https://indianexpress.com/article/cities/mumba...
#
#                                                title  \
# 0  Pune activists, citizens demand clarity on ame...
# 1  Ram Mandir inauguration: Govt should declare J...
# 2  PM Modi to visit TN tomorrow to inaugurate new...
# 3  894 total Covid cases registered in Maharashtr...
# 4  Thane Rave Party: Two arrested organisers rema...
#
#                                               author  \
# 0  Shubham TiggaPune |Updated: January 2, 2024 09...
# 1  :Express News ServiceMumbai |Updated: January ...
# 2  :Express Web DeskChennai |Updated: January 2, ...
# ...

# %%
cat_df = pd.read_csv("/Users/sngirish/personal_work/mtech-learning/data-science/project/Media-Bias-Analysis-in-Indian-News-Articles/articles/cat/indian_express_article_content_2024_progress_50_cat.csv")

# %%
cat_df.head()
# Out:
#                                                 text  \
# 0  Introduction of the new Bharatiya Nyay Sanhita...
# 1  BJP leader Atul Bhatkhalkar on Monday wrote a ...
# 2  Prime Minister Narendra Modi is slated to visi...
# 3  Maharashtra registered a total of 894 new COVI...
# 4  Two persons who were arrested early on Sunday ...
#
#                                                  url  \
# 0  https://indianexpress.com/article/cities/pune/...
# 1  https://indianexpress.com/article/cities/mumba...
# 2  https://indianexpress.com/article/cities/chenn...
# 3  https://indianexpress.com/article/cities/mumba...
# 4  https://indianexpress.com/article/cities/mumba...
#
#                                                title  \
# 0  Pune activists, citizens demand clarity on ame...
# 1  Ram Mandir inauguration: Govt should declare J...
# 2  PM Modi to visit TN tomorrow to inaugurate new...
# 3  894 total Covid cases registered in Maharashtr...
# ...

# %%
import pandas as pd

biased_df = pd.read_csv("./articles/bias/indian_express_article_content_2024_progress_1000_cat_bias_analysis.csv")

# %%
biased_df.head(100)
# Out:
#                                                 text  \
# 0  Introduction of the new Bharatiya Nyay Sanhita...
# 1  BJP leader Atul Bhatkhalkar on Monday wrote a ...
# 2  Prime Minister Narendra Modi is slated to visi...
# 3  Maharashtra registered a total of 894 new COVI...
# 4  Two persons who were arrested early on Sunday ...
# 5  Veteran BJP leader and former Karnataka chief ...
# 6  As many as 816 motorists were booked by the po...
# 7  Four people, including the contractor, behind ...
# 8  The Manipur government imposed curfew across t...
# 9  Three people were killed and six others injure...
#
#                                                  url  \
# 0  https://indianexpress.com/article/cities/pune/...
# 1  https://indianexpress.com/article/cities/mumba...
# 2  https://indianexpress.com/article/cities/chenn...
# 3  https://indianexpress.com/article/cities/mumba...
# 4  https://indianexpress.com/article/cities/mumba...
# 5  https://indianexpress.com/article/cities/banga...
# ...
